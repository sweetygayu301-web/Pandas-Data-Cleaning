# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/mega_data_cleaning_dataset.xlsx - Sheet1.csv")
df
# Out:
#       Customer_ID              Name  Age  Gender                  Country  \
# 0            1191     Larry Wallace   31   Other                      NaN
# 1            8287      Shawn Palmer   20    Male                   Uganda
# 2            6574     Daniel Cortez  105     Mle               Tajikistan
# 3            3377      Cindy Barber  100  Female                    Chile
# 4            5107     William Patel  110     Mle              Timor-Leste
# ...           ...               ...  ...     ...                      ...
# 9995         8287    Deborah Garcia   11     Mle               Cape Verde
# 9996         8932     Donald Pineda   69  Female                      NaN
# 9997         6328  Alexandria Moore   -5   Other  Cocos (Keeling) Islands
# 9998         8121               NaN  110    Male        Equatorial Guinea
# 9999         2851  Kathleen Leblanc   67     Mle                  Albania
#
#              State                City                               Email  \
# ...

# %%
#1.	Identify and remove duplicate rows in the dataset.
df=df.drop_duplicates()
df
# Out:
#       Customer_ID              Name  Age  Gender                  Country  \
# 0            1191     Larry Wallace   31   Other                      NaN
# 1            8287      Shawn Palmer   20    Male                   Uganda
# 2            6574     Daniel Cortez  105     Mle               Tajikistan
# 3            3377      Cindy Barber  100  Female                    Chile
# 4            5107     William Patel  110     Mle              Timor-Leste
# ...           ...               ...  ...     ...                      ...
# 9995         8287    Deborah Garcia   11     Mle               Cape Verde
# 9996         8932     Donald Pineda   69  Female                      NaN
# 9997         6328  Alexandria Moore   -5   Other  Cocos (Keeling) Islands
# 9998         8121               NaN  110    Male        Equatorial Guinea
# 9999         2851  Kathleen Leblanc   67     Mle                  Albania
#
#              State                City                               Email  \
# ...

# %%
#2.	Identify and remove duplicate Customer_IDs.
df=df.drop_duplicates(subset=['Customer_ID'])
df
# Out:
#       Customer_ID              Name  Age  Gender            Country  \
# 0            1191     Larry Wallace   31   Other                NaN
# 1            8287      Shawn Palmer   20    Male             Uganda
# 2            6574     Daniel Cortez  105     Mle         Tajikistan
# 3            3377      Cindy Barber  100  Female              Chile
# 4            5107     William Patel  110     Mle        Timor-Leste
# ...           ...               ...  ...     ...                ...
# 9991         2919      Tyler Hunter   44  Female               Guam
# 9993         8538      Harry Carter  108  Female            Tokelau
# 9994         1905     Deborah Young  128       f             Tuvalu
# 9998         8121               NaN  110    Male  Equatorial Guinea
# 9999         2851  Kathleen Leblanc   67     Mle            Albania
#
#           State                City                               Email  \
# 0      Arkansas           Janetfort  gonzalezbrandi@shaffer-lambert.com
# ...

# %%
#3.	Identify and remove duplicate Emails.
df=df.drop_duplicates(subset=['Email'])
df
# Out:
#       Customer_ID              Name  Age  Gender            Country  \
# 0            1191     Larry Wallace   31   Other                NaN
# 1            8287      Shawn Palmer   20    Male             Uganda
# 2            6574     Daniel Cortez  105     Mle         Tajikistan
# 3            3377      Cindy Barber  100  Female              Chile
# 4            5107     William Patel  110     Mle        Timor-Leste
# ...           ...               ...  ...     ...                ...
# 9991         2919      Tyler Hunter   44  Female               Guam
# 9993         8538      Harry Carter  108  Female            Tokelau
# 9994         1905     Deborah Young  128       f             Tuvalu
# 9998         8121               NaN  110    Male  Equatorial Guinea
# 9999         2851  Kathleen Leblanc   67     Mle            Albania
#
#           State                City                               Email  \
# 0      Arkansas           Janetfort  gonzalezbrandi@shaffer-lambert.com
# ...

# %%
#4.	Identify and remove duplicate Product_IDs.
df=df.drop_duplicates(subset=['Product_ID'])
df
# Out:
#       Customer_ID              Name  Age  Gender               Country  \
# 0            1191     Larry Wallace   31   Other                   NaN
# 1            8287      Shawn Palmer   20    Male                Uganda
# 2            6574     Daniel Cortez  105     Mle            Tajikistan
# 3            3377      Cindy Barber  100  Female                 Chile
# 4            5107     William Patel  110     Mle           Timor-Leste
# ...           ...               ...  ...     ...                   ...
# 2955          675               NaN   74    Male  Netherlands Antilles
# 3032         1437     Paula Wheeler  111     Mle             Greenland
# 3034         3786      Karen Miller   22       f                France
# 3039          201  Kirk Clayton PhD   80       f    Russian Federation
# 3298         5796        Angel Hood   53     Mle                   NaN
#
#                State                City                               Email  \
# ...

# %%
#5.	Fill missing Name values with "Unknown".
df['Name'].fillna('Unknown')
# Out:
# 0          Larry Wallace
# 1           Shawn Palmer
# 2          Daniel Cortez
# 3           Cindy Barber
# 4          William Patel
#               ...
# 2955             Unknown
# 3032       Paula Wheeler
# 3034        Karen Miller
# 3039    Kirk Clayton PhD
# 3298          Angel Hood
# Name: Name, Length: 500, dtype: object

# %%
#6.	Fill missing Email values with "noemail@example.com".
df['Email'].fillna('noemail@example.com')
# Out:
# 0       gonzalezbrandi@shaffer-lambert.com
# 1                 davidmendoza@hotmail.com
# 2                    hoffmancole@yahoo.com
# 3                 carpenterlinda@yahoo.com
# 4          blairivan@lyons-christensen.org
#                        ...
# 2955                  nicholas42@yahoo.com
# 3032                       hmunoz@kent.com
# 3034                      zsmall@gmail.com
# 3039                   cbennett@wright.com
# 3298                      omar32@yahoo.com
# Name: Email, Length: 500, dtype: object

# %%
#7.	Fill missing Product_Name values with "Misc".
df['Product_Name'].fillna('Misc')
# Out:
# 0         police
# 1       training
# 2        compare
# 3           miss
# 4           deal
#           ...
# 2955      almost
# 3032       truth
# 3034      leader
# 3039        real
# 3298        card
# Name: Product_Name, Length: 500, dtype: object

# %%
#8.	Fill missing Category values with "Misc".
df['Category'].fillna('Misc')
# Out:
# 0              Misc
# 1          Clothing
# 2              Misc
# 3              Misc
# 4       Electronics
#            ...
# 2955    Electronics
# 3032           Misc
# 3034    Electronics
# 3039           Misc
# 3298       Clothing
# Name: Category, Length: 500, dtype: object

# %%
#Fill missing Feedback_Score values with the median feedback per product.
x= df.groupby('Product_ID')['Feedback_Score'].transform('median')
df['Feedback_Score'] = df['Feedback_Score'].fillna(x)
df
# Out:
# /tmp/ipython-input-1050604239.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Feedback_Score'] = df['Feedback_Score'].fillna(x)
#       Customer_ID              Name  Age  Gender               Country  \
# 0            1191     Larry Wallace   31   Other                   NaN
# 1            8287      Shawn Palmer   20    Male                Uganda
# 2            6574     Daniel Cortez  105     Mle            Tajikistan
# 3            3377      Cindy Barber  100  Female                 Chile
# 4            5107     William Patel  110     Mle           Timor-Leste
# ...           ...               ...  ...     ...                   ...
# 2955          675               NaN   74    Male  Netherlands Antilles
# ...

# %%
#10.	Fill missing Quantity values with 1
df['Quantity'].fillna(1)
# Out:
# 0       12
# 1        9
# 2        0
# 3        9
# 4        7
#         ..
# 2955     3
# 3032    15
# 3034    15
# 3039     5
# 3298    15
# Name: Quantity, Length: 500, dtype: int64

# %%
#11.	Remove rows where Price is negative.
df = df[df['Price'] <0]

# %%
#12.	Remove rows where Price is zero.
#df = df[df['Price']>=0]
#df

# %%
#13.	Remove rows where Quantity is negative.
df = df[df['Quantity'] >= 0]
df
# Out:
#       Customer_ID               Name  Age  Gender                   Country  \
# 29           8701  Michelle Townsend   82   Other                      Fiji
# 38           4343     David Anderson   12    Male                 Hong Kong
# 44           4881         Mark Pitts  112       f                Cape Verde
# 127          6983   Roberta Caldwell   82     Mle                   Burundi
# 137          5992      Thomas Rogers   17   Other  Central African Republic
# 143          2728     John Velazquez  122       f                    Brazil
# 146           897          Paul Carr   25  Female                     Kenya
# 187          6805    Annette Schultz   68   Other                       NaN
# 200          6943         Tara Brown   68       f          Pitcairn Islands
# 289          7515       Cassie Davis   98       f                       NaN
# 297          2796                NaN   33   Other                       NaN
# ...

# %%
#14.	Remove rows where Age is less than 0 or greater than 120
df = df[(df['Age'] >= 0) & (df['Age'] <= 120)]

# %%
#15.	Remove rows where Feedback_Score is less than 1 or greater than 5
df = df[(df['Feedback_Score'] >= 1) & (df['Feedback_Score'] <= 5)]

# %%
#16.	Remove rows where Delivery_Date is before Purchase_Date
df = df[pd.to_datetime(df['Delivery_Date']) >= pd.to_datetime(df['Purchase_Date'])]

# %%
#17.	Fix typos in Gender column (e.g., "Mle" → "Male", "f" → "Female").
df['Gender'] = df['Gender'].replace({'Mle': 'Male', 'mle': 'Male', 'f': 'Female', 'F': 'Female', 'Othr': 'Other'})

# %%
#18.	Fix typos in Payment_Type column.
df['Payment_Type'] = df['Payment_Type'].replace({'Cahs': 'Cash', 'CASH': 'Cash','up':'UPI','Crdit':'Credit','credit cart': 'Credit Card','debit': 'Debit Card', 'online pay': 'Online Payment'})

# %%
#19.	Standardize Account_Status column (Active/Inactive/Banned).
df['Account_Status'] = df['Account_Status'].str.title()
df['Account_Status'] = df['Account_Status'].replace({'Actv': 'Active', 'Inactiv': 'Inactive', 'Banned_User': 'Banned'})

# %%
#20.	Remove invalid email addresses.
df=df[df['Email'].str.contains(r'^[\w\.-]+@[\w\.-]+\.\w+$', na=False)]

# %%
#21.Fetch all orders where Price > 500.
orders_price=df[df['Price']>500]

# %%
#22.Fetch all orders where Feedback_Score < 3.
FBS=df[df['Feedback_Score']<3]

# %%
#23.Fetch all VIP customers (Customer_Loyalty = "VIP") with Total_Purchase > 1000.
vip_customers=df[(df['Customer_Loyalty'] == 'VIP') & (df['Total_Purchase']>1000)]

# %%
#24.Fetch all orders where Account_Status = "Banned".
df=df[df['Account_Status']=='Banned']

# %%
#25.Fetch all orders delivered late (Delivery_Date - Purchase_Date > 7 days).
df['Delivery_Date'] = pd.to_datetime(df['Delivery_Date'])
df['Purchase_Date'] = pd.to_datetime(df['Purchase_Date'])
late_orders= df[(df['Delivery_Date']-df['Purchase_Date']).dt.days>7]

# %%
#26.Fetch all products in the "Electronics" category.
df=df[df['Category']=='Electronics']

# %%
#27.Fetch all customers from "India".
df=df[df['Country']=='India']

# %%
#28.Fetch all orders where Quantity > 10.
df=df[df['Quantity'] > 10]

# %%
#29.Fetch all orders where Discount > 50
df=df[df['Discount']>10]

# %%
#30.Fetch all orders where Price * Quantity > 1000.
df=df[df['Price']*df['Quantity']>1000]

# %%
#31.using Customer_ID, fetch all orders with the customer details
customer_df=df[['Customer_ID', 'Name', 'Email', 'Country', 'Account_Status']].drop_duplicates()

# %%
#32.Using Product_ID, fetch all orders with product details.
product_df=df_customer[['Product_ID', 'Product_Name', 'Category', 'Price']].drop_duplicates()

# %%
#33.Combine customer and product info into the orders table.
merged_df=df.merge(customer_df, on='Customer_ID', how='left')
merged_df=merged_df.merge(product_df, on='Product_ID', how='left')

# %%
#34.Calculate total purchase per customer (sum(Price * Quantity)).
df['Total_Purchase']=df['Price'] * df['Quantity']
total_purchase=df.groupby('Customer_ID')['Total_Purchase'].sum()

# %%
#35.Calculate average feedback per product.
avf=df.groupby('Product_ID')['Feedback_Score'].mean().reset_index(name='Average_Feedback')

# %%
#36.Identify customers who only ordered "Electronics".
electronics_customers = df.groupby('Customer_ID')['Category'].nunique()
electronics_only = electronics_customers[electronics_customers == 1].index

# %%
#37.Identify top 10 VIP customers by total purchase amount.
vip= total_purchase_per_customer.sort_values(by='Total_Purchase_Amount', ascending=True).head(10)

#top_vip = df[df.get('Customer_Loyalty') == 'VIP'].groupby('Customer_ID')['Total_Purchase'].sum().nlargest(10)

# %%
#38.Identify products that were never ordered.
orderproduct=df['Product_ID'].unique()
allproduct=df[~df['Product_ID'].isin(orderproduct)]

# %%
#39.Identify orders with missing customer info
missing_customer = df[df['Customer_ID'].isna()]

# %%
#40.Identify orders with missing product info.
missing_product = df[df['Product_ID'].isna()]
orders_missing_product = df[df['Product_Name'].isna() | df['Category'].isna()]

# %%
#41.Add a column Total_Purchase = Price * Quantity.
df['Total_Purchase'] = df['Price'] * df['Quantity']

# %%
#42.Add a column Discounted_Price = Price - Discount.
df['Discounted_Price'] = df['Price'] - df['Discount']

# %%
#43.Add a column Delivery_Duration = Delivery_Date - Purchase_Date.
df['Purchase_Date'] = pd.to_datetime(df['Purchase_Date'])
df['Delivery_Date'] = pd.to_datetime(df['Delivery_Date'])
df['Delivery_Duration'] = (df['Delivery_Date'] - df['Purchase_Date']).dt.days

# %%
#44.Create Age_Group for customers (Child/Teen/Adult/Senior).
def age_group(age):
    if age < 13:
        return 'Child'
    elif age < 20:
        return 'Teen'
    elif age < 60:
        return 'Adult'
    else:
        return 'Senior'

df['age_group'] = df['Age'].apply(age_group)

# %%
#45.Create Loyalty_Level based on total purchase.
def loyalty_level(total):
    if total < 1000:
        return 'Bronze'
    elif total < 5000:
        return 'Silver'
    elif total < 10000:
        return 'Gold'
    else:
        return 'Platinum'

df['Loyalty_Level'] = df['Total_Purchase'].apply(loyalty_level)

# %%
#46.Encode Gender numerically (Male=1, Female=2, Other=3).
df['Gender_Code'] = df['Gender'].map({'Male': 1, 'Female': 2, 'Other': 3})

# %%
#47.Encode Account_Status numerically.
df['Account_Status_Code'] = df['Account_Status'].map({'Active': 1, 'Inactive': 0})

# %%
#48.Standardize Country names (capitalize first letters).
df['Country'] = df['Country'].str.title()

# %%
#49.Standardize Payment_Type strings.
df['Payment_Type'] = df['Payment_Type'].str.strip().str.title()

# %%
#50.Remove leading/trailing spaces and lowercase all string columns.
for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].astype(str).str.strip().str.lower()

# %%
#51.Find top 5 products by total revenue (Price * Quantity).
top_products = df.groupby('Product_ID')['Total_Purchase'].sum().nlargest(5)

# %%
#52.Find top 5 customers by total purchase.
top_5_customers=(df.groupby(['Customer_ID'])['Total_Purchase'].sum().reset_index().sort_values(by='Total_Purchase', ascending=False).head(5))

# %%
#53.Calculate average discount per category.
avg_dis=(df.groupby('Category')['Discount'].mean().reset_index().sort_values(by='Discount', ascending=False))

# %%
#54.Calculate average feedback per product category.
avg_feedback=(df.groupby('Category')['Feedback_Score'].mean().reset_index().sort_values(by='Feedback_Score', ascending=False))

# %%
#55.Identify the most popular payment type.
popular_payment=(df['Payment_Type'].value_counts().reset_index().rename(columns={'index':'Payment_Type','Payment_Type':'Count'}).head(1))

# %%
#56.Find the customer with the highest single order value.
df['Order_Value'] = df['Price'] * df['Quantity']
highest_order = df.sort_values(by='Order_Value', ascending=False).head(1)

# %%
#57.Identify customers who placed more than 5 orders.
customer_orders=df.groupby('Customer_ID').size()
frequent_customers=customer_orders[customer_orders > 5]

# %%
#58.Sort orders by Delivery_Duration descending.
df=df.sort_values(by='Delivery_Duration',ascending=False)

# %%
#59.Find products with maximum and minimum feedback.
mafp=df.sort_values(by='Feedback_Score', ascending=False).head(1)[['Product_ID', 'Product_Name', 'Feedback_Score']]
mifp=df.sort_values(by='Feedback_Score', ascending=True).head(1)[['Product_ID', 'Product_Name', 'Feedback_Score']]

# %%
#60.Group orders by Country and Category, and calculate total Total_Purchase.
TP= (df.groupby(['Country', 'Category'])['Total_Purchase'].sum().reset_index().sort_values(by='Total_Purchase',ascending=False))
